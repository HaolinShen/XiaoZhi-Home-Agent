# %%
from src.models import LightDevice, ACDevice, ACMode

light = LightDevice(device_id="lining_room_light",
                    name="客厅灯",
                    brightness=80,
                    color="暖白")

light.turn_on()
print(light.to_status_text())
light.turn_off()
print(light.to_status_text())
# Out:
# 客厅灯 (lining_room_light): 🟢 开启 | 亮度: 80% | 色温: 暖白
# 客厅灯 (lining_room_light): 🔴 关闭 | 亮度: 80% | 色温: 暖白
